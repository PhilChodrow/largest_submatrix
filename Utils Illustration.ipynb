# %%
from matplotlib import pyplot as plt
from algs import utils
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Read A Matrix

# %%
path = 'data/chr4_chr20.txt'
m = utils.read_data(path)
plt.imshow(m)
